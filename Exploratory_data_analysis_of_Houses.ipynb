# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-AI-creator/Abdul-AI-creator/blob/main/Exploratory_data_analysis_of_Houses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis housing in london

# %%
import pandas as pd
df = pd.read_csv("/content/housing_in_london_monthly_variables.csv")
df
# Out:
#              date            area  average_price       code  houses_sold  \
# 0      01/01/1995  city of london          91449  E09000001         17.0
# 1      01/02/1995  city of london          82203  E09000001          7.0
# 2      01/03/1995  city of london          79121  E09000001         14.0
# 3      01/04/1995  city of london          77101  E09000001          7.0
# 4      01/05/1995  city of london          84409  E09000001         10.0
# ...           ...             ...            ...        ...          ...
# 13544  01/09/2019         england         249942  E92000001      64605.0
# 13545  01/10/2019         england         249376  E92000001      68677.0
# 13546  01/11/2019         england         248515  E92000001      67814.0
# 13547  01/12/2019         england         250410  E92000001          NaN
# 13548  01/01/2020         england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag
# 0               NaN             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
#  6   borough_flag   13549 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 741.1+ KB

# %%
df.describe()
# Out:
#        average_price    houses_sold  no_of_crimes  borough_flag
# count   1.354900e+04   13455.000000   7439.000000  13549.000000
# mean    2.635197e+05    3893.994129   2158.352063      0.733338
# std     1.876175e+05   12114.402476    902.087742      0.442230
# min     4.072200e+04       2.000000      0.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000      0.000000
# 50%     2.229190e+05     371.000000   2132.000000      1.000000
# 75%     3.368430e+05    3146.000000   2582.000000      1.000000
# max     1.463378e+06  132163.000000   7461.000000      1.000000

# %%
df.isna().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# borough_flag        0
# dtype: int64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 4

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# no_of_crimes     0.450956
# houses_sold      0.006938
# date             0.000000
# area             0.000000
# average_price    0.000000
# code             0.000000
# borough_flag     0.000000
# dtype: float64

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <Axes: >

# %%
missing_percentages[missing_percentages != 0].plot(kind='pie')
# Out:
# <Axes: >

# %%
fig = px.imshow(df, title="Heatmap Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x='average_price', y='houses_sold', color='area', title="Bubble Chart Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.area(df, x='date', y='houses_sold', color='area', title="Area Chart Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Columns we'll analyze:
#
# 1. City
# 2. Start Time
# 3. Start Lat, Start Lng
# 4. Temperature
# 5. Weather Condition

# %%
df.area
# Out:
# 0        city of london
# 1        city of london
# 2        city of london
# 3        city of london
# 4        city of london
#               ...
# 13544           england
# 13545           england
# 13546           england
# 13547           england
# 13548           england
# Name: area, Length: 13549, dtype: object

# %%
city_count = df.area.unique()
len(city_count)
# Out:
# 45

# %%
city_val = df.area.value_counts()
city_val
# Out:
# area
# hackney                   302
# south east                302
# enfield                   302
# tower hamlets             302
# redbridge                 301
# richmond upon thames      301
# southwark                 301
# sutton                    301
# waltham forest            301
# wandsworth                301
# westminster               301
# inner london              301
# outer london              301
# city of london            301
# merton                    301
# north east                301
# north west                301
# yorks and the humber      301
# east midlands             301
# west midlands             301
# east of england           301
# london                    301
# south west                301
# newham                    301
# kingston upon thames      301
# lewisham                  301
# lambeth                   301
# barnet                    301
# bexley                    301
# brent                     301
# bromley                   301
# ...

# %%
city_val[:20].plot(kind = 'barh')
# Out:
# <Axes: ylabel='area'>

# %%
city_val[:20].plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
city_val[city_val== 301]
# Out:
# area
# redbridge                 301
# richmond upon thames      301
# southwark                 301
# sutton                    301
# waltham forest            301
# wandsworth                301
# westminster               301
# inner london              301
# outer london              301
# city of london            301
# merton                    301
# north east                301
# north west                301
# yorks and the humber      301
# east midlands             301
# west midlands             301
# east of england           301
# london                    301
# south west                301
# newham                    301
# kingston upon thames      301
# lewisham                  301
# lambeth                   301
# barnet                    301
# bexley                    301
# brent                     301
# bromley                   301
# camden                    301
# croydon                   301
# ealing                    301
# greenwich                 301
# ...

# %%
df.date = pd.to_datetime(df.date)
df.date
# Out:
# 0       1995-01-01
# 1       1995-01-02
# 2       1995-01-03
# 3       1995-01-04
# 4       1995-01-05
#            ...
# 13544   2019-01-09
# 13545   2019-01-10
# 13546   2019-01-11
# 13547   2019-01-12
# 13548   2020-01-01
# Name: date, Length: 13549, dtype: datetime64[ns]

# %%
sns.distplot(df.date.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# <ipython-input-26-ad41eed3f9ea>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.date.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='date'>

# %%
sns.distplot(df.date.dt.dayofweek, bins=7, kde=True, norm_hist=True)
# Out:
# <ipython-input-29-8a4b388fe081>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.date.dt.dayofweek, bins=7, kde=True, norm_hist=True)
# <Axes: xlabel='date', ylabel='Density'>

# %%
sns.distplot(df.date.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# <ipython-input-30-6af001342af6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.date.dt.month, bins=12, kde=False, norm_hist=True)
# <Axes: xlabel='date'>

# %%
sundays_start_time = df.date[df.date.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# <ipython-input-31-1499eec5e37c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='date'>

# %%
df_2019 = df[df.date.dt.year == 2019]
df_2019

# %%
df_2019_Bing = df_2019[df_2019.area == 'barking and dagenham']
df_2019_Bing
# Out:
#           date                  area  average_price       code  houses_sold  \
# 589 2019-01-01  barking and dagenham         297181  E09000002        119.0
# 590 2019-01-02  barking and dagenham         293881  E09000002        139.0
# 591 2019-01-03  barking and dagenham         294585  E09000002        154.0
# 592 2019-01-04  barking and dagenham         296360  E09000002        119.0
# 593 2019-01-05  barking and dagenham         296555  E09000002        109.0
# 594 2019-01-06  barking and dagenham         295600  E09000002        124.0
# 595 2019-01-07  barking and dagenham         299538  E09000002        141.0
# 596 2019-01-08  barking and dagenham         300702  E09000002        154.0
# 597 2019-01-09  barking and dagenham         305277  E09000002        125.0
# 598 2019-01-10  barking and dagenham         304153  E09000002        131.0
# 599 2019-01-11  barking and dagenham         305882  E09000002        124.0
# ...

# %%
sns.distplot(df_2019_Bing.date.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# <ipython-input-36-0c042098e74a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019_Bing.date.dt.month, bins=12, kde=False, norm_hist=True)
# <Axes: xlabel='date'>

# %%
sns.histplot(city_val,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
df.area.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes',
#        'borough_flag'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
fig = px.histogram(df,x='average_price',y = 'houses_sold',color='area',color_discrete_sequence=['red','blue','yellow','orange'])
fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Pie Charts

# %% [markdown]
# Proportion of Total Houses Sold by Area

# %%
house_sold_ar = df.groupby('area')['houses_sold'].sum().dropna()
fig = px.pie(house_sold_ar, values = 'houses_sold', names = house_sold_ar.index , title = 'Proportion of total house by area')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 2. Proportion of Areas with and Without Borough Status

# %%
borough_counts =df['borough_flag'].value_counts()
fig=px.pie(borough_counts , values = borough_counts.values , names =['Borough','Not Borough'] , title ='Proportion of borough vs non borough')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Distribution of **Recorded Crimes** by Area

# %%
area_crime = df.groupby('area')['no_of_crimes'].sum().dropna()
fig = px.pie(area_crime , values ='no_of_crimes',names = area_crime.index, title = 'distribution of Record Cirme by Area' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import folium
import pandas as pd

# Adding sample coordinates for each area (replace with actual coordinates)
# Sample data with coordinates (substitute with actual latitude and longitude data)
data_with_coords = pd.DataFrame({
    'area': ['Area1', 'Area2', 'Area3', 'Area4'],
    'average_price': [450000, 550000, 300000, 700000],
    'latitude': [51.509865, 51.517222, 51.529444, 51.541111],
    'longitude': [-0.118092, -0.136222, -0.134167, -0.125556]
})

# Step 2: Initialize the map centered around London
m = folium.Map(location=[51.5074, -0.1278], zoom_start=10)

# Step 3: Add a circle marker for each area
for idx, row in data_with_coords.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=10,  # Adjust radius for better visualization
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=f"{row['area']}: £{row['average_price']}"
    ).add_to(m)

# Save the map as an HTML file or display it
m.save("london_housing_map_without_geojson.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
