# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-AI-creator/Abdul-AI-creator/blob/main/bitcoin_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import opendatasets as od
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# %%
od.download('https://www.kaggle.com/datasets/mczielinski/bitcoin-historical-data')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: abdulraheem09
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/mczielinski/bitcoin-historical-data
# ...
# 100%|██████████| 100M/100M [00:00<00:00, 131MB/s]

# %%
os.listdir('bitcoin-historical-data')
# Out:
# ['bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv']

# %%
bitcoin_df =pd.read_csv('/content/bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')

# %%
bitcoin_df
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
bitcoin_df.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  4.857377e+06  3.613769e+06  3.613769e+06  3.613769e+06  3.613769e+06
# mean   1.471301e+09  6.009024e+03  6.013357e+03  6.004488e+03  6.009014e+03
# std    8.428019e+07  8.996247e+03  9.003521e+03  8.988778e+03  8.996360e+03
# min    1.325318e+09  3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00
# 25%    1.398179e+09  4.438600e+02  4.440000e+02  4.435200e+02  4.438600e+02
# 50%    1.471428e+09  3.596970e+03  3.598190e+03  3.595620e+03  3.597000e+03
# 75%    1.544288e+09  8.627270e+03  8.632980e+03  8.621090e+03  8.627160e+03
# max    1.617149e+09  6.176356e+04  6.178183e+04  6.167355e+04  6.178180e+04
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# count  3.613769e+06       3.613769e+06    3.613769e+06
# mean   9.323249e+00       4.176284e+04    6.008935e+03
# std    3.054989e+01       1.518248e+05    8.995992e+03
# min    0.000000e+00       0.000000e+00    3.800000e+00
# ...

# %%
mean_close = bitcoin_df['Close'].mean()
bitcoin_df['Open']=bitcoin_df['Close'].apply(lambda x:0 if x <= mean_close   else 1)

# %%
bitcoin_df
# Out:
#           Timestamp  Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920     0      4.39      4.39      4.39      0.455581
# 1        1325317980     1       NaN       NaN       NaN           NaN
# 2        1325318040     1       NaN       NaN       NaN           NaN
# 3        1325318100     1       NaN       NaN       NaN           NaN
# 4        1325318160     1       NaN       NaN       NaN           NaN
# ...             ...   ...       ...       ...       ...           ...
# 4857372  1617148560     1  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620     1  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680     1  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740     1  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800     1  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# 0                 2.000000        4.390000
# ...

# %%
x,y =bitcoin_df['Open'], bitcoin_df['Close']

# %%
y
# Out:
# 0              4.39
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 4857372    58686.00
# 4857373    58685.81
# 4857374    58723.84
# 4857375    58760.59
# 4857376    58778.18
# Name: Close, Length: 4857377, dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
numeric_col = bitcoin_df.select_dtypes(include=np.number).columns.tolist()

# %%
numeric_col
# Out:
# ['Timestamp',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume_(BTC)',
#  'Volume_(Currency)',
#  'Weighted_Price']

# %%
bitcoin_df[numeric_col].isna().sum()
# Out:
# Timestamp                  0
# Open                       0
# High                 1243608
# Low                  1243608
# Close                1243608
# Volume_(BTC)         1243608
# Volume_(Currency)    1243608
# Weighted_Price       1243608
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')

# %%
imputer.fit(bitcoin_df[numeric_col])
# Out:
# SimpleImputer()

# %%
list(imputer.statistics_)
# Out:
# [1471300766.5042922,
#  0.5652081359960325,
#  6013.357081612021,
#  6004.4880035054775,
#  6009.013545016297,
#  9.32324922268781,
#  41762.84239707858,
#  6008.934800288798]

# %%
bitcoin_df[numeric_col] = imputer.transform(bitcoin_df[numeric_col])

# %%
bitcoin_df[numeric_col]
# Out:
#             Timestamp  Open          High           Low         Close  \
# 0        1.325318e+09   0.0      4.390000      4.390000      4.390000
# 1        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# 2        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# 3        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# 4        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# ...               ...   ...           ...           ...           ...
# 4857372  1.617149e+09   1.0  58714.310000  58686.000000  58686.000000
# 4857373  1.617149e+09   1.0  58693.430000  58683.970000  58685.810000
# 4857374  1.617149e+09   1.0  58723.840000  58693.430000  58723.840000
# 4857375  1.617149e+09   1.0  58770.380000  58742.180000  58760.590000
# 4857376  1.617149e+09   1.0  58778.180000  58755.970000  58778.180000
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
bitcoin_df
# Out:
#             Timestamp  Open          High           Low         Close  \
# 0        1.325318e+09   0.0      4.390000      4.390000      4.390000
# 1        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# 2        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# 3        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# 4        1.325318e+09   1.0   6013.357082   6004.488004   6009.013545
# ...               ...   ...           ...           ...           ...
# 4857372  1.617149e+09   1.0  58714.310000  58686.000000  58686.000000
# 4857373  1.617149e+09   1.0  58693.430000  58683.970000  58685.810000
# 4857374  1.617149e+09   1.0  58723.840000  58693.430000  58723.840000
# 4857375  1.617149e+09   1.0  58770.380000  58742.180000  58760.590000
# 4857376  1.617149e+09   1.0  58778.180000  58755.970000  58778.180000
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
x ,y =bitcoin_df['Open'], bitcoin_df['Close']

# %%
x
# Out:
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 4857372    1.0
# 4857373    1.0
# 4857374    1.0
# 4857375    1.0
# 4857376    1.0
# Name: Open, Length: 4857377, dtype: float64

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25)

# %%
len(x_train) / 4857377 * 100
# Out:
# 74.99998455956785

# %%
len(x_test) / 4857377
# Out:
# 0.2500001544043215

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(bitcoin_df[numeric_col])
# Out:
# MinMaxScaler()

# %%
from typing import List
print("Minimum")
list(scaler.data_min_)
# Out:
# Minimum
# [1325317920.0, 0.0, 3.8, 1.5, 1.5, 0.0, 0.0, 3.8]

# %%
print("Maximum")
list(scaler.data_max_)
# Out:
# Maximum
# [1617148800.0,
#  1.0,
#  61781.83,
#  61673.55,
#  61781.8,
#  5853.8521659,
#  13900672.407,
#  61716.205341]

# %%
bitcoin_df[numeric_col] = scaler.transform(bitcoin_df[numeric_col])

# %%
bitcoin_df[numeric_col]
# Out:
#             Timestamp  Open      High       Low     Close  Volume_(BTC)  \
# 0        0.000000e+00   0.0  0.000010  0.000047  0.000047      0.000078
# 1        2.055985e-07   1.0  0.097277  0.097337  0.097240      0.001593
# 2        4.111971e-07   1.0  0.097277  0.097337  0.097240      0.001593
# 3        6.167956e-07   1.0  0.097277  0.097337  0.097240      0.001593
# 4        8.223941e-07   1.0  0.097277  0.097337  0.097240      0.001593
# ...               ...   ...       ...       ...       ...           ...
# 4857372  9.999992e-01   1.0  0.950346  0.951557  0.949890      0.000237
# 4857373  9.999994e-01   1.0  0.950008  0.951525  0.949887      0.001246
# 4857374  9.999996e-01   1.0  0.950500  0.951678  0.950503      0.000291
# 4857375  9.999998e-01   1.0  0.951254  0.952468  0.951098      0.000123
# 4857376  1.000000e+00   1.0  0.951380  0.952692  0.951382      0.000463
#
#          Volume_(Currency)  Weighted_Price
# 0             1.438779e-07        0.000010
# ...

# %%
print(bitcoin_df[numeric_col].shape)
# Out:
# (4857377, 8)

# %% [markdown]
# **Saving Processed Data to Disk**

# %%
pip install pyarrow

# %%
bitcoin_df.to_parquet('bitcoin_df analyze classification')

# %%
# %%time
pd.DataFrame(bitcoin_df).to_parquet('bitcoin_df analyze classsification')
# Out:
# CPU times: user 2.07 s, sys: 925 ms, total: 2.99 s
# Wall time: 2.86 s

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(solver='liblinear')
